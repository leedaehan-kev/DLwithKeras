# %% [markdown]
# # 0. 오늘은 Regression 문제를 풀어 볼 예정입니다.
#
#  - 오늘의 목표는 sin 함수를 예측해보는 LSTM 모델을 만드는 것입니다.

# %% [markdown]
# ## 1.우선 필요 라이브러리를 import 합니다.

# %%
import numpy as np 
import matplotlib.pyplot as plt

import torch
from torch.utils import data

import torch.optim as optim

# %% [markdown]
# ## 2. 딥러닝 모델을 설계할 때 활용하는 장비 확인

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')           

print('Using PyTorch version:', torch.__version__, ' Device:', device)
# Out:
# Using PyTorch version: 1.11.0  Device: cpu

# %% [markdown]
# # 3.모델 만들기
#
#
# 아래의 모델에서 many-to-many LSTM (맨 오른쪽) 모델을 만들어봅시다.
#
#  - LSTM의 Hidden Unit의 수는 16으로 하세요
#
#  - LSTM의 입력의 크기는 5개입니다. 즉, 5개의 입력값으로 5개의 출력값을 예측해 봅시다.
#
#
# ![RNN.png](attachment:RNN.png)

# %%
import torch.nn as nn

class LSTM(nn.Module):
    def __init__(self):
        super(LSTM, self).__init__()     
        self.lstm = nn.LSTM(input_size=1, hidden_size=16, batch_first=True, num_layers = 1) 
        self.fc = nn.Linear(16,1)

    def forward(self,x,h_state):
        r_out, h_state = self.lstm(x)
        out = self.fc(r_out)        
        return out.squeeze()

# %% [markdown]
# # 3. Data를 만들어 봅시다
#
#  - 입력값은 SIN 함수의 일부인 연속된 5개 값입니다.
#
#  - many-to-many LSTM 모델은 5개의 SIN함수의 일부를 입력받아서 다음 번 숫자 5개를 예측합니다.
#
#  - T는 1주기를 몇개의 값으로 표현했는지는 나타냅니다.
#
#  - n은 몇번의 주기를 만들지 표현합니다.
#
#  - amp 는 sin함수의 크기를 나타냅니다.
#
#  - alpha 는 시작점의 위치를 나타냅니다.

# %%
def sin_data(x, T=100):
    return np.sin(2.0*np.pi*x/T)

def toy_problem(n = 3, T=100, amp = 3, alpha = 0):
    x = np.arange(0, n*T + 1) + alpha
    return amp*sin_data(x, T)

# %% [markdown]
#  - sin_dataset: 새로운 데이터를 모델에 입력하기 위해 Dataset를 정의합니다.
#
#  - prepare_data: 입력은 n, T, alpha를 받습니다. 출력은 sin 함수의 연속된 값을 5개씩으로 데이터를 만들고 이에 대한 label을 sin함수의 6번째 값으로 지정합니다.

# %%
class sin_dataset(data.Dataset):
    
    def __init__(self, r_data, label):
        self.r_data = r_data.unsqueeze(-1)
        self.label = label
    
    def __len__(self):
        return len(self.label)
    
    def __getitem__(self,index):
        return self.r_data[index], self.label[index] 

def prepare_data(n,T, alpha=0):
    
    target = toy_problem(n=n, T=T, amp=3, alpha=0)
    plt.plot(target)
    plt.show()
    
    rd = []
    labels = []
    
    for i in range(T*n - 5):
        rd.append(target[i:i+5])
        labels.append(target[i+1:i+6]) 
     
    
    return torch.Tensor(rd), torch.Tensor(labels)

# %% [markdown]
# - train, validation, test 데이터셋을 만들고 이를 DataLoader에 입력합니다.

# %%
BATCH_SIZE = 16
T = 100
n = 5

pre_train = prepare_data(n,T)
pre_test = prepare_data(int(n/4),T,n+1)

train = sin_dataset(pre_train[0], pre_train[1])
test = sin_dataset(pre_test[0], pre_test[1])


train, val = data.random_split(train,[int(T*n*0.7),len(train)-int(T*n*0.7)])

train_loader = torch.utils.data.DataLoader(dataset=train, batch_size=BATCH_SIZE, shuffle=False)
val_loader = torch.utils.data.DataLoader(dataset=val, batch_size=BATCH_SIZE, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# C:\Users\kakoo\anaconda3\envs\kev\lib\site-packages\ipykernel_launcher.py:27: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:210.)

# %% [markdown]
# ## 7. 학습 준비하기
#
# 1) 1 epoch를 학습할 수 있는 함수 만들기
#
# 2) Test와 Validation data의 정확도 계산할 수 있는 함수 만들기

# %%
def training_epoch(train_loader, network, loss_func, optimizer, epoch):
    train_losses = []
    train_correct = 0
    log_interval = 300
    
    for batch_idx, (r_data, label) in enumerate(train_loader):
        r_data, label = r_data.to(device), label.to(device)

        # 미분값의 초기화
        optimizer.zero_grad()
        
        init_h = torch.zeros(1,BATCH_SIZE,16).to(device)
        c_0 = torch.zeros(1,BATCH_SIZE,16).to(device)
        
        outputs = network.forward(r_data, (init_h,c_0))
        

        # MSE 함수를 적용하여 loss를 구하고 저장하기
        
        loss = loss_func(outputs, label)
        train_losses.append(loss.item())

        # Gradinet 구하기
        loss.backward()

        # weight값 update 하기
        optimizer.step()

        # 학습 상황 출력
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.2f}%)]\tLoss: {:.6f}'
                  .format(epoch, batch_idx * len(label), len(train_loader.dataset),100. * batch_idx / len(train_loader),
                          loss.item()))
            
    return train_losses

# %%
def test_epoch(test_loader, network, loss_func, val = False):
    correct = 0
    
    test_losses = []
    
    with torch.no_grad():
        for batch_idx, (image, label) in enumerate(test_loader):
            image, label = image.to(device), label.to(device)

            # Forward propagration 계산하기.
            init_h = torch.zeros(1,BATCH_SIZE,16).to(device)
            c_0 = torch.zeros(1,BATCH_SIZE,16).to(device)
            outputs = network.forward(image, (init_h,c_0))

            # MSE 함수를 적용하여 loss를 구하기
            loss = loss_func(outputs, label)
            test_losses.append(loss.item())


        #중간결과 출력
        if val is True:
            print('Validation set: Loss: {:.5f}\n'.format(loss))
        
        else:
            print('Test set: Loss: {:.5f}\n'.format(loss))
        
    return test_losses

# %% [markdown]
# ## 8. 위 정의된 함수로 학습 함수 만들기
#
# - Adam Optimizer를 사용하여 학습시키기
#
# - MSELoss() 함수를 사용할 것

# %%
def training(network, learning_rate = 0.001):
    
    epoches = 200
    
    cls_loss = torch.nn.MSELoss()
    optimizer = optim.Adam(network.parameters(),lr=0.003)
    
    train_losses_per_epoch = []
    test_losses_per_epoch = []
  
    for epoch in range(epoches):
                
        # 모델를 학습 중이라고 선언하기
        network.train()
        
        train_losses = training_epoch(train_loader,network,cls_loss,optimizer, epoch)
        
        # epoch 별로 loss 평균값, 정확도 구하기
        average_loss = np.mean(train_losses)
        train_losses_per_epoch.append(average_loss)
        
        
        # epoch 별로 정확도 출력
        print('\nTraining set: Loss {:.6f}'.format(average_loss))

        
        ### 학습 중에 test 결과 보기
        
        # 모델 test 중인 것을 선언하기
        network.eval()
        
        correct = 0
        with torch.no_grad():
            test_losses = test_epoch(train_loader, network, cls_loss, True)

        test_losses_per_epoch.append(np.mean(test_losses))
        
    with torch.no_grad():
        test_losses = test_epoch(test_loader, network, cls_loss, False)
        
    return train_losses_per_epoch, test_losses_per_epoch

# %%
model = LSTM().to(device)
train_loss, test_loss = training(model)
# Out:
# Train Epoch: 0 [0/350 (0.00%)]	Loss: 4.680584
#
# Training set: Loss 4.096418
# Validation set: Loss: 3.76394
#
# Train Epoch: 1 [0/350 (0.00%)]	Loss: 3.263683
#
# Training set: Loss 2.549444
# Validation set: Loss: 1.86145
#
# Train Epoch: 2 [0/350 (0.00%)]	Loss: 1.646387
#
# Training set: Loss 1.192302
# Validation set: Loss: 0.93497
#
# Train Epoch: 3 [0/350 (0.00%)]	Loss: 1.064033
#
# Training set: Loss 0.816481
# Validation set: Loss: 0.76329
#
# Train Epoch: 4 [0/350 (0.00%)]	Loss: 0.897548
#
# Training set: Loss 0.602882
# Validation set: Loss: 0.57405
#
# Train Epoch: 5 [0/350 (0.00%)]	Loss: 0.594061
#
# Training set: Loss 0.417749
# Validation set: Loss: 0.37687
#
# Train Epoch: 6 [0/350 (0.00%)]	Loss: 0.384269
#
# Training set: Loss 0.285156
# Validation set: Loss: 0.27539
#
# Train Epoch: 7 [0/350 (0.00%)]	Loss: 0.274919
#
# Training set: Loss 0.218753
# Validation set: Loss: 0.22139
#
# Train Epoch: 8 [0/350 (0.00%)]	Loss: 0.217522
#
# Training set: Loss 0.173691
# Validation set: Loss: 0.17574
#
# Train Epoch: 9 [0/350 (0.00%)]	Loss: 0.172211
#
# Training set: Loss 0.136873
# Validation set: Loss: 0.13780
#
# Train Epoch: 10 [0/350 (0.00%)]	Loss: 0.135552
#
# Training set: Loss 0.107050
# Validation set: Loss: 0.10764
#
# Train Epoch: 11 [0/350 (0.00%)]	Loss: 0.106110
#
# Training set: Loss 0.083625
# Validation set: Loss: 0.08415
#
# Train Epoch: 12 [0/350 (0.00%)]	Loss: 0.083329
#
# Training set: Loss 0.065709
# Validation set: Loss: 0.06611
#
# Train Epoch: 13 [0/350 (0.00%)]	Loss: 0.066220
#
# Training set: Loss 0.052175
# Validation set: Loss: 0.05238
#
# Train Epoch: 14 [0/350 (0.00%)]	Loss: 0.053491
#
# Training set: Loss 0.042016
# Validation set: Loss: 0.04202
#
# Train Epoch: 15 [0/350 (0.00%)]	Loss: 0.044097
#
# Training set: Loss 0.034490
# Validation set: Loss: 0.03434
#
# Train Epoch: 16 [0/350 (0.00%)]	Loss: 0.037343
#
# Training set: Loss 0.029063
# Validation set: Loss: 0.02877
#
# Train Epoch: 17 [0/350 (0.00%)]	Loss: 0.032712
#
# Training set: Loss 0.025293
# Validation set: Loss: 0.02487
#
# Train Epoch: 18 [0/350 (0.00%)]	Loss: 0.029728
#
# Training set: Loss 0.022775
# Validation set: Loss: 0.02220
#
# Train Epoch: 19 [0/350 (0.00%)]	Loss: 0.027923
#
# Training set: Loss 0.021139
# Validation set: Loss: 0.02040
#
# Train Epoch: 20 [0/350 (0.00%)]	Loss: 0.026874
#
# Training set: Loss 0.020073
# Validation set: Loss: 0.01916
#
# Train Epoch: 21 [0/350 (0.00%)]	Loss: 0.026248
#
# Training set: Loss 0.019344
# Validation set: Loss: 0.01825
#
# Train Epoch: 22 [0/350 (0.00%)]	Loss: 0.025817
#
# Training set: Loss 0.018795
# Validation set: Loss: 0.01755
#
# Train Epoch: 23 [0/350 (0.00%)]	Loss: 0.025456
#
# Training set: Loss 0.018336
# Validation set: Loss: 0.01696
#
# Train Epoch: 24 [0/350 (0.00%)]	Loss: 0.025112
#
# Training set: Loss 0.017918
# Validation set: Loss: 0.01645
#
# Train Epoch: 25 [0/350 (0.00%)]	Loss: 0.024768
#
# Training set: Loss 0.017520
# Validation set: Loss: 0.01600
#
# Train Epoch: 26 [0/350 (0.00%)]	Loss: 0.024422
#
# Training set: Loss 0.017132
# Validation set: Loss: 0.01559
#
# Train Epoch: 27 [0/350 (0.00%)]	Loss: 0.024074
#
# Training set: Loss 0.016751
# Validation set: Loss: 0.01522
#
# Train Epoch: 28 [0/350 (0.00%)]	Loss: 0.023723
#
# Training set: Loss 0.016375
# Validation set: Loss: 0.01486
#
# Train Epoch: 29 [0/350 (0.00%)]	Loss: 0.023369
#
# Training set: Loss 0.016004
# Validation set: Loss: 0.01450
#
# Train Epoch: 30 [0/350 (0.00%)]	Loss: 0.023012
#
# Training set: Loss 0.015639
# Validation set: Loss: 0.01415
#
# Train Epoch: 31 [0/350 (0.00%)]	Loss: 0.022654
#
# Training set: Loss 0.015280
# Validation set: Loss: 0.01380
#
# Train Epoch: 32 [0/350 (0.00%)]	Loss: 0.022296
#
# Training set: Loss 0.014928
# Validation set: Loss: 0.01346
#
# Train Epoch: 33 [0/350 (0.00%)]	Loss: 0.021940
#
# Training set: Loss 0.014587
# Validation set: Loss: 0.01313
#
# Train Epoch: 34 [0/350 (0.00%)]	Loss: 0.021586
#
# Training set: Loss 0.014254
# Validation set: Loss: 0.01281
#
# Train Epoch: 35 [0/350 (0.00%)]	Loss: 0.021235
#
# Training set: Loss 0.013932
# Validation set: Loss: 0.01250
#
# Train Epoch: 36 [0/350 (0.00%)]	Loss: 0.020885
#
# Training set: Loss 0.013620
# Validation set: Loss: 0.01221
#
# Train Epoch: 37 [0/350 (0.00%)]	Loss: 0.020537
#
# Training set: Loss 0.013318
# Validation set: Loss: 0.01192
#
# Train Epoch: 38 [0/350 (0.00%)]	Loss: 0.020191
#
# Training set: Loss 0.013024
# Validation set: Loss: 0.01165
#
# Train Epoch: 39 [0/350 (0.00%)]	Loss: 0.019845
#
# Training set: Loss 0.012740
# Validation set: Loss: 0.01139
#
# Train Epoch: 40 [0/350 (0.00%)]	Loss: 0.019501
#
# Training set: Loss 0.012464
# Validation set: Loss: 0.01113
#
# Train Epoch: 41 [0/350 (0.00%)]	Loss: 0.019159
#
# Training set: Loss 0.012196
# Validation set: Loss: 0.01089
#
# Train Epoch: 42 [0/350 (0.00%)]	Loss: 0.018819
#
# Training set: Loss 0.011935
# Validation set: Loss: 0.01064
#
# Train Epoch: 43 [0/350 (0.00%)]	Loss: 0.018482
#
# Training set: Loss 0.011683
# Validation set: Loss: 0.01041
#
# Train Epoch: 44 [0/350 (0.00%)]	Loss: 0.018148
#
# Training set: Loss 0.011437
# Validation set: Loss: 0.01018
#
# Train Epoch: 45 [0/350 (0.00%)]	Loss: 0.017818
#
# Training set: Loss 0.011199
# Validation set: Loss: 0.00995
#
# Train Epoch: 46 [0/350 (0.00%)]	Loss: 0.017492
#
# Training set: Loss 0.010967
# Validation set: Loss: 0.00973
#
# Train Epoch: 47 [0/350 (0.00%)]	Loss: 0.017172
#
# Training set: Loss 0.010741
# Validation set: Loss: 0.00951
#
# Train Epoch: 48 [0/350 (0.00%)]	Loss: 0.016858
#
# Training set: Loss 0.010521
# Validation set: Loss: 0.00930
#
# Train Epoch: 49 [0/350 (0.00%)]	Loss: 0.016552
#
# Training set: Loss 0.010306
# Validation set: Loss: 0.00910
#
# Train Epoch: 50 [0/350 (0.00%)]	Loss: 0.016256
#
# Training set: Loss 0.010095
# Validation set: Loss: 0.00892
#
# Train Epoch: 51 [0/350 (0.00%)]	Loss: 0.015969
#
# Training set: Loss 0.009889
# Validation set: Loss: 0.00874
#
# Train Epoch: 52 [0/350 (0.00%)]	Loss: 0.015689
#
# Training set: Loss 0.009686
# Validation set: Loss: 0.00857
#
# Train Epoch: 53 [0/350 (0.00%)]	Loss: 0.015410
#
# Training set: Loss 0.009487
# Validation set: Loss: 0.00840
#
# Train Epoch: 54 [0/350 (0.00%)]	Loss: 0.015128
#
# Training set: Loss 0.009292
# Validation set: Loss: 0.00824
#
# Train Epoch: 55 [0/350 (0.00%)]	Loss: 0.014840
#
# Training set: Loss 0.009101
# Validation set: Loss: 0.00807
#
# Train Epoch: 56 [0/350 (0.00%)]	Loss: 0.014547
#
# Training set: Loss 0.008914
# Validation set: Loss: 0.00791
#
# Train Epoch: 57 [0/350 (0.00%)]	Loss: 0.014253
#
# Training set: Loss 0.008732
# Validation set: Loss: 0.00775
#
# Train Epoch: 58 [0/350 (0.00%)]	Loss: 0.013961
#
# Training set: Loss 0.008555
# Validation set: Loss: 0.00760
#
# Train Epoch: 59 [0/350 (0.00%)]	Loss: 0.013674
#
# Training set: Loss 0.008383
# Validation set: Loss: 0.00745
#
# Train Epoch: 60 [0/350 (0.00%)]	Loss: 0.013393
#
# Training set: Loss 0.008216
# Validation set: Loss: 0.00731
#
# Train Epoch: 61 [0/350 (0.00%)]	Loss: 0.013116
#
# Training set: Loss 0.008054
# Validation set: Loss: 0.00717
#
# Train Epoch: 62 [0/350 (0.00%)]	Loss: 0.012845
#
# Training set: Loss 0.007897
# Validation set: Loss: 0.00704
#
# Train Epoch: 63 [0/350 (0.00%)]	Loss: 0.012577
#
# Training set: Loss 0.007744
# Validation set: Loss: 0.00691
#
# Train Epoch: 64 [0/350 (0.00%)]	Loss: 0.012314
#
# Training set: Loss 0.007594
# Validation set: Loss: 0.00678
#
# Train Epoch: 65 [0/350 (0.00%)]	Loss: 0.012055
#
# Training set: Loss 0.007449
# Validation set: Loss: 0.00666
#
# Train Epoch: 66 [0/350 (0.00%)]	Loss: 0.011800
#
# Training set: Loss 0.007308
# Validation set: Loss: 0.00654
#
# Train Epoch: 67 [0/350 (0.00%)]	Loss: 0.011549
#
# Training set: Loss 0.007170
# Validation set: Loss: 0.00642
#
# Train Epoch: 68 [0/350 (0.00%)]	Loss: 0.011302
#
# Training set: Loss 0.007035
# Validation set: Loss: 0.00631
#
# Train Epoch: 69 [0/350 (0.00%)]	Loss: 0.011059
#
# Training set: Loss 0.006904
# Validation set: Loss: 0.00620
#
# Train Epoch: 70 [0/350 (0.00%)]	Loss: 0.010819
#
# Training set: Loss 0.006777
# Validation set: Loss: 0.00609
#
# Train Epoch: 71 [0/350 (0.00%)]	Loss: 0.010583
#
# Training set: Loss 0.006653
# Validation set: Loss: 0.00599
#
# Train Epoch: 72 [0/350 (0.00%)]	Loss: 0.010351
#
# Training set: Loss 0.006532
# Validation set: Loss: 0.00589
#
# Train Epoch: 73 [0/350 (0.00%)]	Loss: 0.010123
#
# Training set: Loss 0.006414
# Validation set: Loss: 0.00579
#
# Train Epoch: 74 [0/350 (0.00%)]	Loss: 0.009898
#
# Training set: Loss 0.006300
# Validation set: Loss: 0.00569
#
# Train Epoch: 75 [0/350 (0.00%)]	Loss: 0.009676
#
# Training set: Loss 0.006188
# Validation set: Loss: 0.00560
#
# Train Epoch: 76 [0/350 (0.00%)]	Loss: 0.009459
#
# Training set: Loss 0.006080
# Validation set: Loss: 0.00551
#
# Train Epoch: 77 [0/350 (0.00%)]	Loss: 0.009244
#
# Training set: Loss 0.005975
# Validation set: Loss: 0.00541
#
# Train Epoch: 78 [0/350 (0.00%)]	Loss: 0.009033
#
# Training set: Loss 0.005872
# Validation set: Loss: 0.00532
#
# Train Epoch: 79 [0/350 (0.00%)]	Loss: 0.008826
#
# Training set: Loss 0.005772
# Validation set: Loss: 0.00524
#
# Train Epoch: 80 [0/350 (0.00%)]	Loss: 0.008622
#
# Training set: Loss 0.005676
# Validation set: Loss: 0.00515
#
# Train Epoch: 81 [0/350 (0.00%)]	Loss: 0.008422
#
# Training set: Loss 0.005582
# Validation set: Loss: 0.00506
#
# Train Epoch: 82 [0/350 (0.00%)]	Loss: 0.008225
#
# Training set: Loss 0.005491
# Validation set: Loss: 0.00498
#
# Train Epoch: 83 [0/350 (0.00%)]	Loss: 0.008033
#
# Training set: Loss 0.005402
# Validation set: Loss: 0.00490
#
# Train Epoch: 84 [0/350 (0.00%)]	Loss: 0.007845
#
# Training set: Loss 0.005317
# Validation set: Loss: 0.00482
#
# Train Epoch: 85 [0/350 (0.00%)]	Loss: 0.007662
#
# Training set: Loss 0.005234
# Validation set: Loss: 0.00474
#
# Train Epoch: 86 [0/350 (0.00%)]	Loss: 0.007484
#
# Training set: Loss 0.005155
# Validation set: Loss: 0.00466
#
# Train Epoch: 87 [0/350 (0.00%)]	Loss: 0.007310
#
# Training set: Loss 0.005078
# Validation set: Loss: 0.00459
#
# Train Epoch: 88 [0/350 (0.00%)]	Loss: 0.007141
#
# Training set: Loss 0.005003
# Validation set: Loss: 0.00452
#
# Train Epoch: 89 [0/350 (0.00%)]	Loss: 0.006976
#
# Training set: Loss 0.004932
# Validation set: Loss: 0.00445
#
# Train Epoch: 90 [0/350 (0.00%)]	Loss: 0.006816
#
# Training set: Loss 0.004863
# Validation set: Loss: 0.00439
#
# Train Epoch: 91 [0/350 (0.00%)]	Loss: 0.006661
#
# Training set: Loss 0.004797
# Validation set: Loss: 0.00432
#
# Train Epoch: 92 [0/350 (0.00%)]	Loss: 0.006510
#
# Training set: Loss 0.004734
# Validation set: Loss: 0.00426
#
# Train Epoch: 93 [0/350 (0.00%)]	Loss: 0.006364
#
# Training set: Loss 0.004673
# Validation set: Loss: 0.00421
#
# Train Epoch: 94 [0/350 (0.00%)]	Loss: 0.006222
#
# Training set: Loss 0.004615
# Validation set: Loss: 0.00415
#
# Train Epoch: 95 [0/350 (0.00%)]	Loss: 0.006084
#
# Training set: Loss 0.004559
# Validation set: Loss: 0.00410
#
# Train Epoch: 96 [0/350 (0.00%)]	Loss: 0.005950
#
# Training set: Loss 0.004506
# Validation set: Loss: 0.00405
#
# Train Epoch: 97 [0/350 (0.00%)]	Loss: 0.005821
#
# Training set: Loss 0.004455
# Validation set: Loss: 0.00400
#
# Train Epoch: 98 [0/350 (0.00%)]	Loss: 0.005696
#
# Training set: Loss 0.004407
# Validation set: Loss: 0.00396
#
# Train Epoch: 99 [0/350 (0.00%)]	Loss: 0.005576
#
# Training set: Loss 0.004361
# Validation set: Loss: 0.00391
#
# Train Epoch: 100 [0/350 (0.00%)]	Loss: 0.005460
#
# Training set: Loss 0.004317
# Validation set: Loss: 0.00387
#
# Train Epoch: 101 [0/350 (0.00%)]	Loss: 0.005349
#
# Training set: Loss 0.004275
# Validation set: Loss: 0.00383
#
# Train Epoch: 102 [0/350 (0.00%)]	Loss: 0.005242
#
# Training set: Loss 0.004236
# Validation set: Loss: 0.00379
#
# Train Epoch: 103 [0/350 (0.00%)]	Loss: 0.005139
#
# Training set: Loss 0.004198
# Validation set: Loss: 0.00375
#
# Train Epoch: 104 [0/350 (0.00%)]	Loss: 0.005040
#
# Training set: Loss 0.004163
# Validation set: Loss: 0.00372
#
# Train Epoch: 105 [0/350 (0.00%)]	Loss: 0.004945
#
# Training set: Loss 0.004129
# Validation set: Loss: 0.00369
#
# Train Epoch: 106 [0/350 (0.00%)]	Loss: 0.004854
#
# Training set: Loss 0.004098
# Validation set: Loss: 0.00365
#
# Train Epoch: 107 [0/350 (0.00%)]	Loss: 0.004767
#
# Training set: Loss 0.004068
# Validation set: Loss: 0.00362
#
# Train Epoch: 108 [0/350 (0.00%)]	Loss: 0.004684
#
# Training set: Loss 0.004040
# Validation set: Loss: 0.00360
#
# Train Epoch: 109 [0/350 (0.00%)]	Loss: 0.004604
#
# Training set: Loss 0.004014
# Validation set: Loss: 0.00357
#
# Train Epoch: 110 [0/350 (0.00%)]	Loss: 0.004528
#
# Training set: Loss 0.003989
# Validation set: Loss: 0.00354
#
# Train Epoch: 111 [0/350 (0.00%)]	Loss: 0.004455
#
# Training set: Loss 0.003966
# Validation set: Loss: 0.00352
#
# Train Epoch: 112 [0/350 (0.00%)]	Loss: 0.004386
#
# Training set: Loss 0.003945
# Validation set: Loss: 0.00350
#
# Train Epoch: 113 [0/350 (0.00%)]	Loss: 0.004320
#
# Training set: Loss 0.003925
# Validation set: Loss: 0.00348
#
# Train Epoch: 114 [0/350 (0.00%)]	Loss: 0.004257
#
# Training set: Loss 0.003906
# Validation set: Loss: 0.00346
#
# Train Epoch: 115 [0/350 (0.00%)]	Loss: 0.004197
#
# Training set: Loss 0.003889
# Validation set: Loss: 0.00344
#
# Train Epoch: 116 [0/350 (0.00%)]	Loss: 0.004139
#
# Training set: Loss 0.003873
# Validation set: Loss: 0.00342
#
# Train Epoch: 117 [0/350 (0.00%)]	Loss: 0.004085
#
# Training set: Loss 0.003858
# Validation set: Loss: 0.00341
#
# Train Epoch: 118 [0/350 (0.00%)]	Loss: 0.004033
#
# Training set: Loss 0.003844
# Validation set: Loss: 0.00339
#
# Train Epoch: 119 [0/350 (0.00%)]	Loss: 0.003983
#
# Training set: Loss 0.003832
# Validation set: Loss: 0.00338
#
# Train Epoch: 120 [0/350 (0.00%)]	Loss: 0.003936
#
# Training set: Loss 0.003820
# Validation set: Loss: 0.00337
#
# Train Epoch: 121 [0/350 (0.00%)]	Loss: 0.003891
#
# Training set: Loss 0.003810
# Validation set: Loss: 0.00335
#
# Train Epoch: 122 [0/350 (0.00%)]	Loss: 0.003848
#
# Training set: Loss 0.003800
# Validation set: Loss: 0.00334
#
# Train Epoch: 123 [0/350 (0.00%)]	Loss: 0.003808
#
# Training set: Loss 0.003792
# Validation set: Loss: 0.00333
#
# Train Epoch: 124 [0/350 (0.00%)]	Loss: 0.003769
#
# Training set: Loss 0.003784
# Validation set: Loss: 0.00332
#
# Train Epoch: 125 [0/350 (0.00%)]	Loss: 0.003732
#
# Training set: Loss 0.003777
# Validation set: Loss: 0.00332
#
# Train Epoch: 126 [0/350 (0.00%)]	Loss: 0.003697
#
# Training set: Loss 0.003770
# Validation set: Loss: 0.00331
#
# Train Epoch: 127 [0/350 (0.00%)]	Loss: 0.003663
#
# Training set: Loss 0.003765
# Validation set: Loss: 0.00330
#
# Train Epoch: 128 [0/350 (0.00%)]	Loss: 0.003631
#
# Training set: Loss 0.003759
# Validation set: Loss: 0.00329
#
# Train Epoch: 129 [0/350 (0.00%)]	Loss: 0.003600
#
# Training set: Loss 0.003755
# Validation set: Loss: 0.00328
#
# Train Epoch: 130 [0/350 (0.00%)]	Loss: 0.003571
#
# Training set: Loss 0.003751
# Validation set: Loss: 0.00328
#
# Train Epoch: 131 [0/350 (0.00%)]	Loss: 0.003543
#
# Training set: Loss 0.003747
# Validation set: Loss: 0.00327
#
# Train Epoch: 132 [0/350 (0.00%)]	Loss: 0.003516
#
# Training set: Loss 0.003743
# Validation set: Loss: 0.00326
#
# Train Epoch: 133 [0/350 (0.00%)]	Loss: 0.003490
#
# Training set: Loss 0.003740
# Validation set: Loss: 0.00326
#
# Train Epoch: 134 [0/350 (0.00%)]	Loss: 0.003465
#
# Training set: Loss 0.003737
# Validation set: Loss: 0.00325
#
# Train Epoch: 135 [0/350 (0.00%)]	Loss: 0.003441
#
# Training set: Loss 0.003734
# Validation set: Loss: 0.00325
#
# Train Epoch: 136 [0/350 (0.00%)]	Loss: 0.003418
#
# Training set: Loss 0.003731
# Validation set: Loss: 0.00324
#
# Train Epoch: 137 [0/350 (0.00%)]	Loss: 0.003396
#
# Training set: Loss 0.003729
# Validation set: Loss: 0.00324
#
# Train Epoch: 138 [0/350 (0.00%)]	Loss: 0.003375
#
# Training set: Loss 0.003726
# Validation set: Loss: 0.00323
#
# Train Epoch: 139 [0/350 (0.00%)]	Loss: 0.003354
#
# Training set: Loss 0.003723
# Validation set: Loss: 0.00322
#
# Train Epoch: 140 [0/350 (0.00%)]	Loss: 0.003335
#
# Training set: Loss 0.003721
# Validation set: Loss: 0.00322
#
# Train Epoch: 141 [0/350 (0.00%)]	Loss: 0.003316
#
# Training set: Loss 0.003718
# Validation set: Loss: 0.00321
#
# Train Epoch: 142 [0/350 (0.00%)]	Loss: 0.003298
#
# Training set: Loss 0.003715
# Validation set: Loss: 0.00321
#
# Train Epoch: 143 [0/350 (0.00%)]	Loss: 0.003281
#
# Training set: Loss 0.003713
# Validation set: Loss: 0.00321
#
# Train Epoch: 144 [0/350 (0.00%)]	Loss: 0.003265
#
# Training set: Loss 0.003710
# Validation set: Loss: 0.00320
#
# Train Epoch: 145 [0/350 (0.00%)]	Loss: 0.003249
#
# Training set: Loss 0.003707
# Validation set: Loss: 0.00320
#
# Train Epoch: 146 [0/350 (0.00%)]	Loss: 0.003235
#
# Training set: Loss 0.003704
# Validation set: Loss: 0.00320
#
# Train Epoch: 147 [0/350 (0.00%)]	Loss: 0.003222
#
# Training set: Loss 0.003701
# Validation set: Loss: 0.00319
#
# Train Epoch: 148 [0/350 (0.00%)]	Loss: 0.003209
#
# Training set: Loss 0.003698
# Validation set: Loss: 0.00319
#
# Train Epoch: 149 [0/350 (0.00%)]	Loss: 0.003198
#
# Training set: Loss 0.003695
# Validation set: Loss: 0.00319
#
# Train Epoch: 150 [0/350 (0.00%)]	Loss: 0.003187
#
# Training set: Loss 0.003692
# Validation set: Loss: 0.00319
#
# Train Epoch: 151 [0/350 (0.00%)]	Loss: 0.003177
#
# Training set: Loss 0.003689
# Validation set: Loss: 0.00319
#
# Train Epoch: 152 [0/350 (0.00%)]	Loss: 0.003168
#
# Training set: Loss 0.003687
# Validation set: Loss: 0.00319
#
# Train Epoch: 153 [0/350 (0.00%)]	Loss: 0.003160
#
# Training set: Loss 0.003685
# Validation set: Loss: 0.00319
#
# Train Epoch: 154 [0/350 (0.00%)]	Loss: 0.003152
#
# Training set: Loss 0.003683
# Validation set: Loss: 0.00318
#
# Train Epoch: 155 [0/350 (0.00%)]	Loss: 0.003144
#
# Training set: Loss 0.003681
# Validation set: Loss: 0.00318
#
# Train Epoch: 156 [0/350 (0.00%)]	Loss: 0.003137
#
# Training set: Loss 0.003680
# Validation set: Loss: 0.00318
#
# Train Epoch: 157 [0/350 (0.00%)]	Loss: 0.003129
#
# Training set: Loss 0.003679
# Validation set: Loss: 0.00318
#
# Train Epoch: 158 [0/350 (0.00%)]	Loss: 0.003122
#
# Training set: Loss 0.003678
# Validation set: Loss: 0.00318
#
# Train Epoch: 159 [0/350 (0.00%)]	Loss: 0.003116
#
# Training set: Loss 0.003677
# Validation set: Loss: 0.00318
#
# Train Epoch: 160 [0/350 (0.00%)]	Loss: 0.003109
#
# Training set: Loss 0.003677
# Validation set: Loss: 0.00318
#
# Train Epoch: 161 [0/350 (0.00%)]	Loss: 0.003103
#
# Training set: Loss 0.003677
# Validation set: Loss: 0.00318
#
# Train Epoch: 162 [0/350 (0.00%)]	Loss: 0.003097
#
# Training set: Loss 0.003677
# Validation set: Loss: 0.00317
#
# Train Epoch: 163 [0/350 (0.00%)]	Loss: 0.003091
#
# Training set: Loss 0.003677
# Validation set: Loss: 0.00317
#
# Train Epoch: 164 [0/350 (0.00%)]	Loss: 0.003086
#
# Training set: Loss 0.003677
# Validation set: Loss: 0.00317
#
# Train Epoch: 165 [0/350 (0.00%)]	Loss: 0.003081
#
# Training set: Loss 0.003677
# Validation set: Loss: 0.00317
#
# Train Epoch: 166 [0/350 (0.00%)]	Loss: 0.003076
#
# Training set: Loss 0.003677
# Validation set: Loss: 0.00317
#
# Train Epoch: 167 [0/350 (0.00%)]	Loss: 0.003071
#
# Training set: Loss 0.003678
# Validation set: Loss: 0.00317
#
# Train Epoch: 168 [0/350 (0.00%)]	Loss: 0.003066
#
# Training set: Loss 0.003679
# Validation set: Loss: 0.00317
#
# Train Epoch: 169 [0/350 (0.00%)]	Loss: 0.003062
#
# Training set: Loss 0.003680
# Validation set: Loss: 0.00317
#
# Train Epoch: 170 [0/350 (0.00%)]	Loss: 0.003058
#
# Training set: Loss 0.003680
# Validation set: Loss: 0.00317
#
# Train Epoch: 171 [0/350 (0.00%)]	Loss: 0.003054
#
# Training set: Loss 0.003682
# Validation set: Loss: 0.00317
#
# Train Epoch: 172 [0/350 (0.00%)]	Loss: 0.003050
#
# Training set: Loss 0.003683
# Validation set: Loss: 0.00317
#
# Train Epoch: 173 [0/350 (0.00%)]	Loss: 0.003046
#
# Training set: Loss 0.003684
# Validation set: Loss: 0.00317
#
# Train Epoch: 174 [0/350 (0.00%)]	Loss: 0.003043
#
# Training set: Loss 0.003686
# Validation set: Loss: 0.00317
#
# Train Epoch: 175 [0/350 (0.00%)]	Loss: 0.003040
#
# Training set: Loss 0.003688
# Validation set: Loss: 0.00317
#
# Train Epoch: 176 [0/350 (0.00%)]	Loss: 0.003037
#
# Training set: Loss 0.003690
# Validation set: Loss: 0.00317
#
# Train Epoch: 177 [0/350 (0.00%)]	Loss: 0.003034
#
# Training set: Loss 0.003692
# Validation set: Loss: 0.00317
#
# Train Epoch: 178 [0/350 (0.00%)]	Loss: 0.003031
#
# Training set: Loss 0.003694
# Validation set: Loss: 0.00317
#
# Train Epoch: 179 [0/350 (0.00%)]	Loss: 0.003028
#
# Training set: Loss 0.003696
# Validation set: Loss: 0.00317
#
# Train Epoch: 180 [0/350 (0.00%)]	Loss: 0.003026
#
# Training set: Loss 0.003699
# Validation set: Loss: 0.00317
#
# Train Epoch: 181 [0/350 (0.00%)]	Loss: 0.003023
#
# Training set: Loss 0.003701
# Validation set: Loss: 0.00317
#
# Train Epoch: 182 [0/350 (0.00%)]	Loss: 0.003021
#
# Training set: Loss 0.003703
# Validation set: Loss: 0.00317
#
# Train Epoch: 183 [0/350 (0.00%)]	Loss: 0.003018
#
# Training set: Loss 0.003705
# Validation set: Loss: 0.00317
#
# Train Epoch: 184 [0/350 (0.00%)]	Loss: 0.003015
#
# Training set: Loss 0.003707
# Validation set: Loss: 0.00317
#
# Train Epoch: 185 [0/350 (0.00%)]	Loss: 0.003013
#
# Training set: Loss 0.003708
# Validation set: Loss: 0.00317
#
# Train Epoch: 186 [0/350 (0.00%)]	Loss: 0.003010
#
# Training set: Loss 0.003710
# Validation set: Loss: 0.00317
#
# Train Epoch: 187 [0/350 (0.00%)]	Loss: 0.003007
#
# Training set: Loss 0.003711
# Validation set: Loss: 0.00317
#
# Train Epoch: 188 [0/350 (0.00%)]	Loss: 0.003004
#
# Training set: Loss 0.003712
# Validation set: Loss: 0.00317
#
# Train Epoch: 189 [0/350 (0.00%)]	Loss: 0.003001
#
# Training set: Loss 0.003714
# Validation set: Loss: 0.00316
#
# Train Epoch: 190 [0/350 (0.00%)]	Loss: 0.002998
#
# Training set: Loss 0.003715
# Validation set: Loss: 0.00316
#
# Train Epoch: 191 [0/350 (0.00%)]	Loss: 0.002995
#
# Training set: Loss 0.003716
# Validation set: Loss: 0.00316
#
# Train Epoch: 192 [0/350 (0.00%)]	Loss: 0.002992
#
# Training set: Loss 0.003717
# Validation set: Loss: 0.00316
#
# Train Epoch: 193 [0/350 (0.00%)]	Loss: 0.002989
#
# Training set: Loss 0.003718
# Validation set: Loss: 0.00316
#
# Train Epoch: 194 [0/350 (0.00%)]	Loss: 0.002986
#
# Training set: Loss 0.003719
# Validation set: Loss: 0.00316
#
# Train Epoch: 195 [0/350 (0.00%)]	Loss: 0.002983
#
# Training set: Loss 0.003720
# Validation set: Loss: 0.00316
#
# Train Epoch: 196 [0/350 (0.00%)]	Loss: 0.002980
#
# Training set: Loss 0.003721
# Validation set: Loss: 0.00316
#
# Train Epoch: 197 [0/350 (0.00%)]	Loss: 0.002977
#
# Training set: Loss 0.003721
# Validation set: Loss: 0.00316
#
# Train Epoch: 198 [0/350 (0.00%)]	Loss: 0.002974
#
# Training set: Loss 0.003722
# Validation set: Loss: 0.00316
#
# Train Epoch: 199 [0/350 (0.00%)]	Loss: 0.002970
#
# Training set: Loss 0.003723
# Validation set: Loss: 0.00316
#
# Test set: Loss: 0.00321

# %%
plt.plot(train_loss)
plt.plot(test_loss)

# %% [markdown]
#  ## 9. LSTM함수가 얼마나 잘 학습 되었는지 확인해 봅시다.
#
#   - 초기값은 sin함수 1주기 후 마지막 5개 값으로 하고
#
#   - 이를 바탕으로 6번째 예측을 한 후
#
#   - 다시 새롭게 추가된 값으로부터 마지막 5개를 새로운 입력으로 하여
#
#   - 3 주기를 반복해봅시다

# %%
init_test = toy_problem(1,T, amp=3)
init_test = torch.tensor(init_test[-5:].reshape(1,5,1), dtype=torch.float).cpu()

h_state = torch.zeros(1,1,16).cpu()    
c_0 = torch.zeros(1,1,16).cpu()  

pred_length = 3

for i in range(T*pred_length):             # 3 주기를 예측 (Generating Sin Wave)
    model = model.cpu()
    init_test = torch.tensor(init_test, dtype=torch.float).cpu()
    r = model(init_test[-5:].reshape(1,5,1), (h_state,c_0)).clone().detach().numpy()
    init_test = np.concatenate((init_test.clone().detach().numpy().squeeze(),r[-1]),axis=None)

    
plt.plot(init_test[5:])
plt.plot(toy_problem(pred_length,T,amp=3))
# Out:
# C:\Users\kakoo\anaconda3\envs\kev\lib\site-packages\ipykernel_launcher.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## 10. 잘 예측이 됩니까? 안된다면 이유가 무엇일까요? 사인함수의 예측에 LSTM 모델을 사용하는 것이 좋은 선택일까요?

# %% [markdown]
# 정답) 처음 한 번만에 좋은 결과를 얻는 것은 힘들다. 이전 과제처럼 몇번 시도를 해보아야 결과값이 제대로 나오는 것을 볼 수 있다. 개인적으로는 LSTM 모델과 RNN 모델 전부 사인 함수의 예측에 사용되어도 좋다고 생각을 한다. (lr, batch size 등등 결과값에 영향을 주는 요소도 많고, 과정이 일정하지 않음에도 불구하고)
#
# LSTM이 sin 함수 예측하는 것이 조금 더 힘들다고 생각하지만, 이 두 모델중에서는 LSTM이 RNN보다 낫다는 생각을 한다. LSTM의 특성(장기 기억 유지) 때문인지, many to many 방식 자체 덕분인지 확실하지는 않지만, LSTM은 학습이 되지 않는 경우에도 파형을 유지하는 최소한의 모습이 보인다. 일례로 RNN에서는 loss를 거의 0에 가깝게 줄여놓아도 파형 모습을 갖추지 않은 경우가 많았다.
#
# 시계열 알고리즘들의 특징이겠지만, 정확한 예측을 한번에 얻는 것은 매우 힘들다. 데이터 예측이 한번 오류가 나면 이는 나중에 큰 영향을 미칠수도 있는 오류가 된다. LSTM은 모델 알고리즘을 보면 이러한 단점이 덜 부각되는 것이 아닌가 하는 생각이 든다.
